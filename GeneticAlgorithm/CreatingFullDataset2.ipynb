# %%
import pandas as pd
from talib import abstract
import numpy as np

# %%
stock = "NSEI"
df = pd.read_csv(f"{stock}.csv", parse_dates=True, usecols=[1,2,3,4,5,6])
df.columns = ["open", "high", "low", "close", "adj close", "volume"]
df.head()
# Out:
#           open         high          low        close    adj close    volume
# 0  8121.950195  8150.250000  8088.600098  8131.700195  8131.700195  145900.0
# 1  8102.399902  8139.299805  8096.350098  8107.899902  8107.899902  138900.0
# 2  8134.350098  8190.549805  8129.799805  8179.500000  8179.500000  167200.0
# 3  8193.650391  8246.400391  8147.649902  8238.150391  8238.150391  156400.0
# 4  8262.549805  8283.049805  8239.200195  8275.049805  8275.049805  124500.0

# %%
df.interpolate(inplace=True)

# %%
df["SMA"] = abstract.SMA(df, timeperiod=7)
df["WMA"] = abstract.WMA(df, timeperiod=7)

# %%
df["RSI"] = abstract.RSI(df, timeperiod=7)

# %%
df["CCI"] = abstract.CCI(df, timeperiod=10)
df["AD"] = abstract.AD(df, timeperiod=10)

# %%
df["STOCHRSIk"] = abstract.STOCHRSI(df, timeperiod=7)["fastk"]
df["STOCHRSId"] = abstract.STOCHRSI(df, timeperiod=7)["fastd"]
df["WILLR"] = abstract.WILLR(df, timeperiod=7)

# %%
df["MACD"] = abstract.MACDFIX(df)["macd"]
df["MACDsignal"] = abstract.MACDFIX(df)["macdsignal"]

# %%
df = df.iloc[33:]
df.head(50)
# Out:
#            open         high          low        close    adj close    volume  \
# 33  7902.299805  7912.299805  7853.299805  7864.149902  7864.149902  125700.0
# 34  7817.600098  7821.399902  7775.700195  7781.899902  7781.899902  152500.0
# 35  7816.549805  7825.399902  7746.049805  7765.399902  7765.399902  137600.0
# 36  7738.500000  7771.250000  7685.450195  7701.700195  7701.700195  135100.0
# 37  7695.500000  7702.850098  7606.899902  7612.500000  7612.500000  140000.0
# 38  7643.299805  7691.950195  7610.000000  7683.299805  7683.299805  140800.0
# 39  7699.600098  7703.049805  7575.299805  7610.450195  7610.450195  167800.0
# 40  7558.200195  7663.950195  7551.049805  7650.049805  7650.049805  148900.0
# 41  7659.149902  7705.000000  7625.100098  7700.899902  7700.899902  134300.0
# 42  7725.250000  7776.600098  7715.750000  7750.899902  7750.899902  154300.0
# 43  7783.049805  7852.899902  7737.549805  7844.350098  7844.350098  175900.0
# 44  7828.899902  7836.149902  7753.350098  7761.950195  7761.950195  191400.0
# 45  7745.649902  7840.750000  7733.450195  7834.450195  7834.450195  126300.0
# 46  7829.399902  7846.299805  7776.850098  7786.100098  7786.100098  125700.0
# 47  7830.450195  7871.450195  7826.100098  7865.950195  7865.950195  117900.0
# 48  7888.750000  7888.750000  7835.500000  7861.049805  7861.049805   93500.0
# 49  7863.200195  7937.200195  7863.000000  7925.149902  7925.149902  122900.0
# 50  7929.200195  7942.149902  7902.750000  7928.950195  7928.950195  113000.0
# 51  7938.600098  7944.750000  7889.850098  7896.250000  7896.250000  106800.0
# 52  7897.799805  7955.549805  7891.149902  7946.350098  7946.350098  150900.0
# 73  9.532580e+01 -12.697953  -75.571128  -95.245744
# 74  6.910416e+01 -53.106226  -72.260786  -90.648752
# 75  3.577083e+01 -95.402766  -75.876345  -87.694271
# 76  1.300699e+01 -78.532836  -74.700455  -85.095508
# 77  3.231313e+01 -44.513261  -66.553025  -81.387011
# 78  4.358963e+01 -85.228808  -67.037143  -78.517037
# 79  3.527394e+01 -92.914149  -73.342348  -77.482100
# 80  1.127650e+01 -90.477929  -83.662215  -78.718123
# 81  2.131628e-14 -97.032227 -108.786267  -84.731752
# 82  8.949713e-01 -82.604269 -126.971201  -93.179641

# %% [markdown]
# # ABOVE USED IN PAPER

# %%
#df["ROC4"] = abstract.ROCP(df, timeperiod=4) * 100

# %%
#df["TRIX"] = abstract.TRIX(df)

# %%
# Select trend from SMA14 and SMA 50
def MA_trend(ma, price):
    return 1 if price > ma else -1

df["SMA_trend"] = df.apply(lambda x: MA_trend(x["SMA"], x["close"]), axis=1)
df["WMA_trend"] = df.apply(lambda x: MA_trend(x["WMA"], x["close"]), axis=1)
# Out:
# <ipython-input-12-b25718390c1c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["SMA_trend"] = df.apply(lambda x: MA_trend(x["SMA"], x["close"]), axis=1)
# <ipython-input-12-b25718390c1c>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["WMA_trend"] = df.apply(lambda x: MA_trend(x["WMA"], x["close"]), axis=1)

# %%
# Select trend from RSI
RSI_trend = [0] * len(df)
for i in range(len(df)):
    if i == 0:
        continue
    lastrsi = df.loc[df.index[i-1], "RSI"]
    rsi = df.loc[df.index[i], "RSI"]
    if rsi > 70:
        RSI_trend[i] = -1
    elif rsi < 30:
        RSI_trend[i] = 1
    elif rsi > lastrsi:
        RSI_trend[i] = 1
    else:
        RSI_trend[i] = -1


df["RSI_trend"] = RSI_trend
# Out:
# <ipython-input-13-bd738f0b9da3>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["RSI_trend"] = RSI_trend

# %%
# Select buy trend from STOCHRSI
STOCHRSIk_trend = [0] * len(df)
STOCHRSId_trend = [0] * len(df)
WILLR_trend = [0] * len(df)
CCI_trend = [0] * len(df)
AD_trend = [0] * len(df)
for i in range(len(df)) :
    if i == 0:
        continue
    lastk = df.loc[df.index[i-1], "STOCHRSIk"]
    lastd = df.loc[df.index[i-1], "STOCHRSId"]
    lastwillr = df.loc[df.index[i-1], "WILLR"]
    lastcci = df.loc[df.index[i-1], "CCI"]
    lastad = df.loc[df.index[i-1], "AD"]
    
    k = df.loc[df.index[i], "STOCHRSIk"]
    d = df.loc[df.index[i], "STOCHRSId"]
    willr = df.loc[df.index[i], "WILLR"]
    cci = df.loc[df.index[i], "CCI"]
    ad = df.loc[df.index[i], "AD"]
    # identify trends
    # K
    if k > lastk:
        STOCHRSIk_trend[i] = 1
    else:
        STOCHRSIk_trend[i] = -1
    # D
    if d > lastd:
        STOCHRSId_trend = 1
    else:
        STOCHRSId_trend = -1
    # WILLR
    if willr > lastwillr:
        WILLR_trend = 1
    else:
        WILLR_trend = -1
    # CCI
    if cci > 150:
        CCI_trend = -1
    elif cci < -150:
        CCI_trend = 1
    elif cci > lastcci:
        CCI_trend = 1
    else:
        CCI_trend = -1
    # WILLR
    if ad > lastad:
        AD_trend = 1
    else:
        AD_trend = -1
        
        
df["STOCHRSIk_trend"] = STOCHRSIk_trend
df["STOCHRSId_trend"] = STOCHRSId_trend
df["WILLR_trend"] = WILLR_trend
df["CCI_trend"] = CCI_trend
df["AD_trend"] = AD_trend
# Out:
# <ipython-input-14-a364b23c8fc3>:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["STOCHRSIk_trend"] = STOCHRSIk_trend
# <ipython-input-14-a364b23c8fc3>:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["STOCHRSId_trend"] = STOCHRSId_trend
# <ipython-input-14-a364b23c8fc3>:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["WILLR_trend"] = WILLR_trend
# <ipython-input-14-a364b23c8fc3>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["CCI_trend"] = CCI_trend
# <ipython-input-14-a364b23c8fc3>:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["AD_trend"] = AD_trend

# %%
# Select trend from MACD
def MACD_trend(macd, signal):
    if macd > signal:
        return 1
    else:
        return -1

df["MACD_trend"] = df.apply(lambda x: MACD_trend(x["MACD"], x["MACDsignal"]), axis=1)
# Out:
# <ipython-input-15-da4b33cb6bde>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MACD_trend"] = df.apply(lambda x: MACD_trend(x["MACD"], x["MACDsignal"]), axis=1)

# %%
# Select trend from TRIX
def TRIX_trend(trix):
    if trix > 0:
        return 1
    else:
        return -1

#df["TRIX_trend"] = df.apply(lambda x: TRIX_trend(x["TRIX"]), axis=1)

# %%
df.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'adj close', 'volume', 'SMA', 'WMA',
#        'RSI', 'CCI', 'AD', 'STOCHRSIk', 'STOCHRSId', 'WILLR', 'MACD',
#        'MACDsignal', 'SMA_trend', 'WMA_trend', 'RSI_trend', 'STOCHRSIk_trend',
#        'STOCHRSId_trend', 'WILLR_trend', 'CCI_trend', 'AD_trend',
#        'MACD_trend'],
#       dtype='object')

# %%
df = df.iloc[1:]
outputdf = df.drop(["open", "high", "low", "volume", "adj close",
         'SMA', 'WMA', 'RSI', 'CCI', 'AD',
         'STOCHRSIk', 'STOCHRSId',
         'WILLR', 'MACD', 'MACDsignal'], axis=1)

# %%
outputdf.isnull().values.any()
# Out:
# False

# %%
len(outputdf)
# Out:
# 1196

# %%
outputdf.head()
# Out:
#           close  SMA_trend  WMA_trend  RSI_trend  STOCHRSIk_trend  \
# 34  7781.899902         -1         -1         -1               -1
# 35  7765.399902         -1         -1          1               -1
# 36  7701.700195         -1         -1          1               -1
# 37  7612.500000         -1         -1          1               -1
# 38  7683.299805         -1         -1          1                1
#
#     STOCHRSId_trend  WILLR_trend  CCI_trend  AD_trend  MACD_trend
# 34               -1            1         -1         1           1
# 35               -1            1         -1         1           1
# 36               -1            1         -1         1           1
# 37               -1            1         -1         1           1
# 38               -1            1         -1         1           1

# %%
outputdf.to_csv(f"{stock}trends2.csv", index=False)

# %%
training_df = outputdf.iloc[:700]
validation_df = outputdf.iloc[700:]

# %%
training_df.to_csv(f"{stock}training2.csv", index=False)
validation_df.to_csv(f"{stock}validation2.csv", index=False)
